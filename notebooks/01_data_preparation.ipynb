# %% [markdown]
# # 01 Data Preparation
#
# Load CSMAR stock-return and market-return exports, standardize columns, and save a cleaned dataset for the event study.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.config import DATA_RAW, DATA_PROCESSED
from src.data_preparation import load_and_clean_returns, save_processed

# %%
# Update these filenames after placing your CSMAR exports in data/raw/.
stock_returns_path = DATA_RAW / "stock_returns.csv"
market_returns_path = DATA_RAW / "market_returns.csv"

cleaned = load_and_clean_returns(stock_returns_path, market_returns_path)
save_processed(cleaned, DATA_PROCESSED / "returns_cleaned.csv")
cleaned.head()
