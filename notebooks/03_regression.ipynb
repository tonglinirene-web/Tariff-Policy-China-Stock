# %% [markdown]
# # 03 Regression
#
# Run the April 7 cross-sectional regression with CAR as the dependent variable and Beta, Size, and IdioVol as explanatory variables.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.config import OUTPUT_TABLES, REGRESSION_EVENT, REGRESSION_WINDOW
from src.regression import prepare_regression_data, run_car_regression, regression_summary_table

# %%
car = pd.read_csv(OUTPUT_TABLES / "car.csv", parse_dates=["event_date"])
window_label = f"[{REGRESSION_WINDOW[0]:+d},{REGRESSION_WINDOW[1]:+d}]"
regression_df = prepare_regression_data(car, REGRESSION_EVENT, window_label)
fit = run_car_regression(regression_df)
summary = regression_summary_table(fit)
summary.to_csv(OUTPUT_TABLES / "april7_regression.csv", index=False)
summary

# %%
print(fit.summary())
